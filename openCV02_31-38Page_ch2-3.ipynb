# %%
import tensorflow as tf 
mnist = tf.keras.datasets.mnist
(train_X, train_y),(test_X, test_y) = mnist.load_data()
train_X, test_X = train_X/255.0, test_X/255.0

from tensorflow.keras.callbacks import ModelCheckpoint
path = "mnist_keras_model.h5"
checkpoint = ModelCheckpoint(filepath=path, monitor="val_accuracy",save_best_only=True, verbose=1)

from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor="val_accuracy", patience=3)


from tensorflow.keras.callbacks import TensorBoard 
log_dir = r"C:\Users\user\logs\fit"
tensor_board = TensorBoard(embeddings_freq=1, histogram_freq=1)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout

model  = Sequential()
model.add(Flatten(input_shape=(28,28))) 
model.add(Dense(360, activation="relu"))
model.add(Dropout(0.1))
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))

# 손실함수 정의 모델평가방법 정의 
model.compile(loss="sparse_categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

# 훈련데이터 학습 
model.fit(train_X, train_y, validation_split=0.2, batch_size=100, epochs= 10, callbacks=[checkpoint, early_stopping, tensor_board])

# tensor_board = TensorBoard(log_dir="tensor_log")
tensor_board = TensorBoard(log_dir = r"C:\Users\user\logs\fit")

model.evaluate(test_X, test_y)
# Out:
# Epoch 1/10
# 472/480 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4872 - loss: 1.6940
# Epoch 1: val_accuracy improved from None to 0.87217, saving model to mnist_keras_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to mnist_keras_model.h5
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6622 - loss: 1.2244 - val_accuracy: 0.8722 - val_loss: 0.5501
# Epoch 2/10
# 475/480 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8260 - loss: 0.6162
# Epoch 2: val_accuracy improved from 0.87217 to 0.90025, saving model to mnist_keras_model.h5
# ...

# %%
# chatGPT 코드(세 가지 콜백을 함께 사용)

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

log_dir = r"C:\Users\user\logs\fit"

checkpoint = ModelCheckpoint(
    filepath="best_model.keras",
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    mode="min",
    restore_best_weights=True,
    verbose=1)

tensorboard = TensorBoard(
    histogram_freq=1)

history = model.fit(
    train_X,
    train_y,
    epochs=10,
    batch_size=50,
    validation_split=0.2,
    callbacks=[
        checkpoint,
        early_stop,
        tensorboard], verbose=1
)
# Out:
# Epoch 1/10
# 942/960 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9268 - loss: 0.2525
# Epoch 1: val_accuracy improved from None to 0.94592, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9273 - loss: 0.2502 - val_accuracy: 0.9459 - val_loss: 0.1934
# Epoch 2/10
# 957/960 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9317 - loss: 0.2351
# Epoch 2: val_accuracy improved from 0.94592 to 0.94983, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9337 - loss: 0.2287 - val_accuracy: 0.9498 - val_loss: 0.1790
# Epoch 3/10
# 949/960 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9381 - loss: 0.2159
# Epoch 3: val_accuracy improved from 0.94983 to 0.95292, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# ...

# %%
# 시각화 그림이 겹쳐서 재설정 후 조치

# 기존 로그 파일 삭제 

import shutil
import os

log_dir = r"C:\Users\user\logs\fit"

if os.path.exists(r"C:\Users\user\logs"):
    shutil.rmtree(r"C:\Users\user\logs")

# 콜백 제 설정 

from tensorflow.keras.callbacks import TensorBoard

log_dir = r"C:\Users\user\logs\fit"

tensorboard = TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    write_graph=True
)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

import tensorflow as tf 
mnist = tf.keras.datasets.mnist
(train_X, train_y),(test_X, test_y) = mnist.load_data()
train_X, test_X = train_X/255.0, test_X/255.0

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

log_dir = r"C:\Users\user\logs\fit"

checkpoint = ModelCheckpoint(
    filepath="best_model.keras",
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

tensorboard = TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    write_graph=True
)

model  = Sequential()
model.add(Flatten(input_shape=(28,28))) 
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.1))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))

# 손실함수 정의 모델평가방법 정의 
model.compile(loss="sparse_categorical_crossentropy", optimizer="Adam", metrics=["accuracy"])

history = model.fit(
    train_X, train_y,
    epochs=10,
    batch_size=50,
    validation_split=0.2,
    callbacks=[
        checkpoint,
        early_stop,
        tensorboard
    ], verbose=1
)

# tensor_board = TensorBoard(log_dir="tensor_log")
tensor_board = TensorBoard(log_dir = r"C:\Users\user\logs\fit")

model.evaluate(test_X, test_y)
# Out:
# Epoch 1/10
# 949/960 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8114 - loss: 0.6210
# Epoch 1: val_accuracy improved from None to 0.95392, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8899 - loss: 0.3683 - val_accuracy: 0.9539 - val_loss: 0.1585
# Epoch 2/10
# 957/960 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9486 - loss: 0.1761
# Epoch 2: val_accuracy improved from 0.95392 to 0.96458, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9508 - loss: 0.1648 - val_accuracy: 0.9646 - val_loss: 0.1197
# Epoch 3/10
# 954/960 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.1173
# Epoch 3: val_accuracy improved from 0.96458 to 0.97025, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# ...

# %%
# 로그 설정 확인 여부

import os

for root, dirs, files in os.walk(r"C:\Users\user\logs"):
    print(root)
    print(files)
# Out:
# C:\Users\user\logs
# []
# C:\Users\user\logs\fit
# []
# C:\Users\user\logs\fit\train
# ['events.out.tfevents.1780551319.MOONLIGHT.16172.18.v2', 'events.out.tfevents.1780618172.MOONLIGHT.14944.14.v2', 'events.out.tfevents.1780618232.MOONLIGHT.14944.16.v2', 'events.out.tfevents.1780618276.MOONLIGHT.14944.18.v2']
# C:\Users\user\logs\fit\validation
# ['events.out.tfevents.1780551322.MOONLIGHT.16172.19.v2', 'events.out.tfevents.1780618174.MOONLIGHT.14944.15.v2', 'events.out.tfevents.1780618235.MOONLIGHT.14944.17.v2', 'events.out.tfevents.1780618280.MOONLIGHT.14944.19.v2']
